# %% [markdown]
# <a href="https://colab.research.google.com/github/babacarmbathie/portfolio-react/blob/main/phenotypage_v1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
# Out:
# True
# Tesla T4

# %%
pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 53.0 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

BASE_PATH = "/content/drive/MyDrive/NAATALAI"

folders = [
    "datasets",
    "datasets/levee",
    "experiments",
    "models",
    "results"
]

for folder in folders:
    os.makedirs(os.path.join(BASE_PATH, folder), exist_ok=True)

print("Structure créée")
# Out:
# Structure créée

# %%
import zipfile

zip_path = "/content/drive/MyDrive/NAATALAI/datasets/levee/F1_V5_30m.v2i.yolov8.zip"

extract_path = "/content/drive/MyDrive/NAATALAI/datasets/levee/F1_V5_30m"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("Dataset extrait")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1359/2513220066.py in <cell line: 0>()
#       6
#       7 with zipfile.ZipFile(zip_path, 'r') as zip_ref:
# ----> 8     zip_ref.extractall(extract_path)
#       9
#      10 print("Dataset extrait")
#
# /usr/lib/python3.12/zipfile/__init__.py in extractall(self, path, members, pwd)
#    1768
#    1769         for zipinfo in members:
# -> 1770             self._extract_member(zipinfo, path, pwd)
#    1771
#    1772     @classmethod
#
# /usr/lib/python3.12/zipfile/__init__.py in _extract_member(self, member, targetpath, pwd)
#    1825
#    1826         with self.open(member, pwd=pwd) as source, \
# -> 1827              open(targetpath, "wb") as target:
#    1828             shutil.copyfileobj(source, target)
#    1829
#
# KeyboardInterrupt:

# %%
import os

dataset_path = "/content/drive/MyDrive/NAATALAI/datasets/levee/F1_V5_30m"

print(os.listdir(dataset_path))
# Out:
# ['train', 'test', 'valid', 'README.roboflow.txt', 'README.dataset.txt', 'data.yaml']

# %%
yaml_content = """
train: ../train/images
val: ../valid/images
test: ../test/images

nc: 1
names: ['plant']
"""

with open("/content/drive/MyDrive/NAATALAI/datasets/levee/F1_V5_30m/data.yaml", "w") as f:
    f.write(yaml_content)

print("data.yaml corrigé")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_583/929042315.py in <cell line: 0>()
#       8 """
#       9
# ---> 10 with open("/content/drive/MyDrive/NAATALAI/datasets/levee/F1_V5_30m/data.yaml", "w") as f:
#      11     f.write(yaml_content)
#      12
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/NAATALAI/datasets/levee/F1_V5_30m/data.yaml'

# %%
# !yolo detect train \
model=yolov8n.pt \
data=/content/drive/MyDrive/NAATALAI/datasets/levee/F1_V5_30m/data.yaml \
epochs=100 \
imgsz=640 \
batch=16 \
name=V1_F1_V5_30m
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.4.50 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
import os

results_path = "/content/runs/detect/V1_F1_V5_30m"

print(os.listdir(results_path))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_583/2100480175.py in <cell line: 0>()
#       3 results_path = "/content/runs/detect/V1_F1_V5_30m"
#       4
# ----> 5 print(os.listdir(results_path))
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/runs/detect/V1_F1_V5_30m'

# %%
from IPython.display import Image

Image("/content/runs/detect/V1_F1_V5_30m/results.png")

# %%
Image("/content/runs/detect/V1_F1_V5_30m/confusion_matrix.png")

# %%
Image("/content/runs/detect/V1_F1_V5_30m/PR_curve.png")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/IPython/core/display.py in _data_and_metadata(self, always_both)
#    1299         try:
# -> 1300             b64_data = b2a_base64(self.data).decode('ascii')
#    1301         except TypeError:
#
# TypeError: a bytes-like object is required, not 'str'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/IPython/core/formatters.py in __call__(self, obj, include, exclude)
#     968
#     969             if method is not None:
# --> 970                 return method(include=include, exclude=exclude)
#     971             return None
#     972         else:
#
# ...

# %%
import shutil

source = "/content/runs/detect/V1_F1_V5_30m/weights/best.pt"

destination = "/content/drive/MyDrive/NAATALAI/models/V1_F1_V5_30m_best.pt"

shutil.copy(source, destination)

print("Modèle sauvegardé dans Drive")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_583/2936486443.py in <cell line: 0>()
#       5 destination = "/content/drive/MyDrive/NAATALAI/models/V1_F1_V5_30m_best.pt"
#       6
# ----> 7 shutil.copy(source, destination)
#       8
#       9 print("Modèle sauvegardé dans Drive")
#
# /usr/lib/python3.12/shutil.py in copy(src, dst, follow_symlinks)
#     433     if os.path.isdir(dst):
#     434         dst = os.path.join(dst, os.path.basename(src))
# --> 435     copyfile(src, dst, follow_symlinks=follow_symlinks)
#     436     copymode(src, dst, follow_symlinks=follow_symlinks)
#     437     return dst
#
# /usr/lib/python3.12/shutil.py in copyfile(src, dst, follow_symlinks)
#     258         os.symlink(os.readlink(src), dst)
#     259     else:
# --> 260         with open(src, 'rb') as fsrc:
#     261             try:
# ...

# %%
from google.colab import files

files.download('/content/runs/detect/V1_F1_V5_30m/weights/best.pt')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_583/1157076602.py in <cell line: 0>()
#       1 from google.colab import files
#       2
# ----> 3 files.download('/content/runs/detect/V1_F1_V5_30m/weights/best.pt')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/files.py in download(filename)
#     228   if not _os.path.exists(filename):
#     229     msg = 'Cannot find file: {}'.format(filename)
# --> 230     raise FileNotFoundError(msg)  # pylint: disable=undefined-variable
#     231
#     232   comm_manager = _IPython.get_ipython().kernel.comm_manager
#
# FileNotFoundError: Cannot find file: /content/runs/detect/V1_F1_V5_30m/weights/best.pt
